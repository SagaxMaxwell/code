# %% [markdown]
# # Matplotlib 直方图
#
# 直方图用于展示数值分布。`hist()` 会把数据分桶并绘制每个桶的频数或密度。
#
# ## 基础直方图
#
# `bins` 控制分桶数量，`density=True` 可以显示概率密度。

# %%
import matplotlib.pyplot as plt
import numpy as np


rng = np.random.default_rng(42)
data = rng.standard_normal(1000)
plt.hist(data, bins=30, density=True, alpha=0.5, histtype="stepfilled", color="steelblue", edgecolor="none")

# %% [markdown]
# ## 多个分布对比
#
# `histtype="stepfilled"` 和透明度适合叠加多个分布。

# %%
x1 = rng.normal(0, 0.8, 1000)
x2 = rng.normal(-2, 1, 1000)
x3 = rng.normal(3, 2, 1000)
kwargs = {"histtype": "stepfilled", "alpha": 0.3, "density": True, "bins": 40}
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)

# %% [markdown]
# ## 只计算分桶
#
# 如果只需要桶计数而不绘图，可以使用 `np.histogram()`。

# %%
counts, bin_edges = np.histogram(data, bins=5)
print(counts)
print(bin_edges)
