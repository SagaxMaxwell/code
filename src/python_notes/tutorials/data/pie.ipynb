# %% [markdown]
# # Matplotlib 饼图
#
# 饼图用于展示部分与整体的占比。`pie()` 支持标签、突出扇区、百分比文本、阴影和图例。
#
# ## 基础饼图
#
# `explode` 可以让指定扇形偏离圆心，`autopct` 控制百分比文本格式。

# %%
import matplotlib.pyplot as plt


labels = "Frogs", "Hogs", "Dogs", "Logs"
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)

fig, ax = plt.subplots()
wedges, texts, autotexts = ax.pie(sizes, explode=explode, labels=labels, autopct="%0.1f%%", shadow=True, startangle=90)
ax.axis("equal")
ax.legend(title="Ingredients", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
